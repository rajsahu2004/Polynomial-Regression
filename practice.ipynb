# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
trainData = pd.read_csv('./data/trainData.csv')
testData = pd.read_csv('./data/testData.csv')
trainData.head()
# Out:
#    x1   x2  x3  x4  x5  x6  x7  x8  x9  x10  ...  x22  x23  x24  x25  x26  \
# 0  40   10  50  80   1   9  43  46  73   82  ...   16    4   99    4   22
# 1  91   25  99  25   3  23   1  46  14   72  ...   33   57   46   48   91
# 2  25   80  79  44  10   2  79   1  73   80  ...   60   37    6   90    9
# 3  26   72  34  67  63  11  74  82  89   92  ...   35   84   85   47   43
# 4   6  100  37  87  87  92  44  78  55   59  ...   45   29   25   21   55
#
#    x27  x28  x29  x30      y
# 0   84   53   90   76   7347
# 1   96   24   32   77   7512
# 2   56    8   29   58   6466
# 3   96   94   43   75  10706
# 4   47   11   29   39   7379
#
# [5 rows x 31 columns]

# %%
trainData = trainData.sort_values('y')
xTrain = trainData.values[:,:-1]
yTrain = trainData.values[:,-1]
xTest = testData.values
plt.scatter(range(len(yTrain)),yTrain)
plt.ylabel('yTrain')
# Out:
# Text(0, 0.5, 'yTrain')
